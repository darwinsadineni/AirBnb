# %% [markdown]
# # Data Preprocessing

# %%
pip install -U klib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import klib
import seaborn as sns

# %%
data = pd.read_csv('/Users/ds/Desktop/Projects/ISM/Data/AB_US_2023.csv')
# Out:
# /var/folders/ml/6gklcgzd4hd14qnjtg492b2c0000gn/T/ipykernel_65441/1948057255.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/Users/ds/Desktop/Projects/ISM/Data/AB_US_2023.csv')

# %%
data.head()
# Out:
#      id                                               name  host_id  \
# 0   958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 3  8339                    Historic Alamo Square Victorian    24215
# 4  8739                Mission Sunshine, with Private Bath     7149
#
#           host_name neighbourhood_group     neighbourhood  latitude  \
# 0             Holly                 NaN  Western Addition  37.77028
# 1  Philip And Tania                 NaN    Bernal Heights  37.74474
# 2             Aaron                 NaN    Haight Ashbury  37.76555
# 3              Rosy                 NaN  Western Addition  37.77564
# 4      Ivan & Wendy                 NaN           Mission  37.76030
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
klib.missingval_plot(data)
# Out:
# GridSpec(6, 6)

# %%
new_data=data.drop_duplicates()

# %%
new_data.shape
# Out:
# (232147, 18)

# %%
new_data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# city                               object
# dtype: object

# %% [markdown]
# ## Remove heading and tailing spaces

# %%
new_data_2 = new_data.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
new_data_2.head()
# Out:
#      id                                               name  host_id  \
# 0   958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 3  8339                    Historic Alamo Square Victorian    24215
# 4  8739                Mission Sunshine, with Private Bath     7149
#
#           host_name neighbourhood_group     neighbourhood  latitude  \
# 0             Holly                 NaN  Western Addition  37.77028
# 1  Philip And Tania                 NaN    Bernal Heights  37.74474
# 2             Aaron                 NaN    Haight Ashbury  37.76555
# 3              Rosy                 NaN  Western Addition  37.77564
# 4      Ivan & Wendy                 NaN           Mission  37.76030
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
new_data_2.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# city                               object
# dtype: object

# %%
new_data_2.to_csv('/Users/ds/Desktop/Projects/ISM/Clean_data/AirBnb_2023_Clean.csv')
