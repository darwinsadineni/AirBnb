# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('/Users/ds/Desktop/Projects/ISM/Data/uszips.csv')

# %%
data.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18027 -66.75266   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36075 -67.17541     Aguada       PR  Puerto Rico  True
# 2  603  18.45744 -67.12225  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16585 -66.93716    Maricao       PR  Puerto Rico  True
# 4  610  18.29110 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN     17126.0    102.6        72001    Adjuntas
# 1          NaN     37895.0    482.5        72003      Aguada
# 2          NaN     49136.0    552.4        72005   Aguadilla
# 3          NaN      5751.0     50.1        72093     Maricao
# 4          NaN     26153.0    272.1        72011      Añasco
#
#                                       county_weights  \
# 0                    {"72001": 98.73, "72141": 1.27}
# 1                                     {"72003": 100}
# ...

# %%
data.shape
# Out:
# (33788, 18)

# %%
new_data=data.drop_duplicates()

# %%
new_data.shape
# Out:
# (33788, 18)

# %%
new_data.dtypes
# Out:
# zip                   int64
# lat                 float64
# lng                 float64
# city                 object
# state_id             object
# state_name           object
# zcta                   bool
# parent_zcta         float64
# population          float64
# density             float64
# county_fips           int64
# county_name          object
# county_weights       object
# county_names_all     object
# county_fips_all      object
# imprecise              bool
# military               bool
# timezone             object
# dtype: object

# %% [markdown]
# ## Remove heading and tailing spaces

# %%
new_data_2 = new_data.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
new_data_2.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18027 -66.75266   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36075 -67.17541     Aguada       PR  Puerto Rico  True
# 2  603  18.45744 -67.12225  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16585 -66.93716    Maricao       PR  Puerto Rico  True
# 4  610  18.29110 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN     17126.0    102.6        72001    Adjuntas
# 1          NaN     37895.0    482.5        72003      Aguada
# 2          NaN     49136.0    552.4        72005   Aguadilla
# 3          NaN      5751.0     50.1        72093     Maricao
# 4          NaN     26153.0    272.1        72011      Añasco
#
#                                       county_weights  \
# 0                    {"72001": 98.73, "72141": 1.27}
# 1                                     {"72003": 100}
# ...

# %%
new_data_2.dtypes
# Out:
# zip                   int64
# lat                 float64
# lng                 float64
# city                 object
# state_id             object
# state_name           object
# zcta                   bool
# parent_zcta         float64
# population          float64
# density             float64
# county_fips           int64
# county_name          object
# county_weights       object
# county_names_all     object
# county_fips_all      object
# imprecise              bool
# military               bool
# timezone             object
# dtype: object

# %%
new_data_2.to_csv('/Users/ds/Desktop/Projects/ISM/Clean_data/Pincodes_population_clean.csv')
